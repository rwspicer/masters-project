# %% [markdown]
# # Results analysis from the forstpy brute force run over the 2019 holidays
#
# analysis of timing an accurcy of mass training results

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../'))
sys.path.insert(0, os.path.abspath('../../forestpy/forestpy'))
from results_imports import *

from scipy import optimize

from matplotlib import rcParams
rcParams["font.family"] = "serif"
rcParams['font.serif'] = ['Times']
rcParams['font.size'] = 14

# %%
data = read_csv('../../results/brute-froce/forestpy-timing-results.csv', index_col=0)

full_data = read_csv('../../forestpy/param-lists/smaller_list_of_random_forests.csv', index_col=0)



i_data = data[np.logical_not(data['train time'].isna())]
i_data.sort_values('abs diff mean')[:10]
# Out:
#                                                      status     e     md  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml   complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml  complete  50.0  100.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml  complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml   complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml   complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml  complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml  complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml  complete  50.0  100.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml  complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml   complete  50.0   60.0
#
#                                                      mf      mln  msl   mss  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml   AUTO  50000.0  8.0   5.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml  AUTO  50000.0  4.0   2.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml  AUTO  50000.0  4.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml   AUTO  50000.0  4.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml   AUTO  50000.0  8.0   2.0
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml  AUTO  50000.0  8.0   2.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml  AUTO  50000.0  2.0  10.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml  AUTO  50000.0  2.0   5.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml  AUTO  50000.0  2.0   2.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml   AUTO  50000.0  2.0   2.0
#
#                                                     tdp     computer  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml   25.0  bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml  25.0  bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml  25.0  bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml   25.0  bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml   50.0  bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml  50.0  bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml  25.0  bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml  25.0  bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml  25.0  bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml   25.0  bristlecone
#
#                                                        train time  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml   0:34:04.931532
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml  0:34:23.755556
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml  0:34:18.075877
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml   0:33:53.060940
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml   1:12:51.591553
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml  1:14:00.400040
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml  0:34:02.142553
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml  0:34:09.556335
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml  0:34:20.209206
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml   0:34:18.246499
#
#                                                      predict time  diff mean  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml   0:00:44.847418  -0.002681
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml  0:00:44.871435  -0.003108
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml  0:00:44.852166  -0.003108
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml   0:00:44.975164  -0.003108
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml   0:00:44.624388  -0.002513
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml  0:00:44.793655  -0.002513
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml  0:00:44.661029  -0.003075
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml  0:00:45.035648  -0.003123
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml  0:00:45.226154  -0.003126
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml   0:00:44.748004  -0.003126
#
#                                                    abs diff mean  diff var  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml        1.146035  3.039994
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml       1.146401  2.976562
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml       1.146401  2.976562
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml        1.146401  2.976562
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml        1.147438  2.940239
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml       1.147438  2.940239
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml       1.147895  2.961271
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml       1.148517  2.961819
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml       1.148612  2.962087
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml        1.148612  2.962087
#
#                                                    abs diff var    median  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml       1.726605  0.008198
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml      1.662335  0.007719
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml      1.662335  0.007719
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml       1.662335  0.007719
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml       1.623631  0.007952
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml      1.623631  0.007952
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml      1.643617  0.007651
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml      1.642738  0.007644
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml      1.642787  0.007652
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml       1.642787  0.007652
#
#                                                    mode  training time (hours)
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml    NaN               0.568037
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml   NaN               0.573265
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml   NaN               0.571688
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml    NaN               0.564739
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml    NaN               1.214331
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml   NaN               1.233444
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml   NaN               0.567262
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml   NaN               0.569321
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml   NaN               0.572280
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml    NaN               0.571735

# %%
# by_time_data = i_data.sort_values('training time (hours)')
# scatter_by_param(by_time_data[by_time_data['training time (hours)'] < .5], param='mln')
# by_time_data[by_time_data['training time (hours)'] < .5].sort_values('abs diff mean')

sparse_sampled_data = i_data.sort_values('abs diff mean').iloc[::40, :]

scatter_by_param(sparse_sampled_data, param='mln')
#sparse_sampled_data.to_csv('../forestpy/param-lists/sparse-list-of-random-forests.csv', index_label='name')

# %%
sparse_sampled_data = i_data.sort_values('abs diff mean').iloc[10::40, :]

sparse_sampled_data['status'] = 'not run'
sparse_sampled_data [['computer',
       'train time', 'predict time', 'diff mean', 'abs diff mean', 'diff var',
       'abs diff var', 'median', 'mode', 'training time (hours)']] = ''
sparse_sampled_data['r^2'] = ''
sparse_sampled_data
# scatter_by_param(sparse_sampled_data, param='mln')
sparse_sampled_data.to_csv('../forestpy/param-lists/sparse-list-of-random-forests.csv', 
    index_label='name', mode='a',header=False
)
### REMEMBER to fix new line
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-01dd488d45cc> in <module>
#       9 # scatter_by_param(sparse_sampled_data, param='mln')
#      10 sparse_sampled_data.to_csv('../forestpy/param-lists/sparse-list-of-random-forests.csv',
# ---> 11     index_label='name', mode='a',header=False
#      12 )
#      13 ### REMEMBER to fix new line
#
# ~/miniconda3/envs/atm-env3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3201             decimal=decimal,
#    3202         )
# -> 3203         formatter.save()
#    3204
#    3205         if path_or_buf is None:
#
# ~/miniconda3/envs/atm-env3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~/miniconda3/envs/atm-env3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../forestpy/param-lists/sparse-list-of-random-forests.csv'

# %%
def scatter_by_param(data, param, add_var=False, title = '', 
    curve_fit = False, x_data = 'abs diff mean',
    colors = [  'slateblue', 'darkblue', 'cornflowerblue','skyblue']):
    """creates color coded scatter plot by param for abs diff mean
    """
    
    symbols = ['o','o','o','o']
    
    vals = data[param].unique()
    
    fig, ax = plt.subplots(figsize = (20, 12))
    #ax.axis([ -.01, .01,-.1, 7])
    
    cix = 0
    for v in vals:
        data[data[param] == v].plot.scatter(
            y = 'training time (hours)', x = x_data  ,
            c=colors[cix], marker=symbols[cix],
            ax=ax, 
            label= hp_lookup[param]  + ' = ' + str(v))
        cix += 1
    if add_var:
        data[data['abs diff var'] < 5].plot.scatter(y = 'training time (hours)', x = x_data ,
                            c='tab:orange',marker = '.', ax = ax, alpha = .5, label="Variance < 5")

    if curve_fit:
        c_data = data[['abs diff mean','training time (hours)']].sort_values(x_data)
        x_data = c_data[x_data]
        y_data = c_data['training time (hours)']
#         curve = lambda  x, a,b,c: a * np.exp(-b * x) + c
        curve = lambda  x, m, b: m*x + b
        popt, pcov = optimize.curve_fit(curve, x_data, y_data)
        
        x_data = np.linspace(x_data.min(), x_data.max(), 50)
        plt.plot(x_data, curve(x_data, *popt), 'r-')
        
#     data.plot.trendline.sort_index(ascending=False).plot(ax=ax)
#     if add_var:
#         data[data['abs diff var'] < 5].plot.scatter(y = 'training time (hours)', x = 'abs diff mean' ,
#                             c='tab:red',marker = '.', ax = ax, alpha = 1, label="Variance < 5")

    ax.set_xlabel('Mean Absoloute Difference From Original Model')
    ax.set_ylabel('Training Time (Hours)')
    ax.legend()
    ax.set_title(title)
    return ax

# %%
rcParams["font.family"] = "serif"
rcParams['font.serif'] = ['Times']
rcParams['font.size'] = 30
ax = scatter_by_param(i_data, 'e', False, title = 'Random Forest Model Mean Absolute Error by Estimators', x_data = 'abs diff mean')
ax.set_xlabel('Mean Absolute Error From Original Model')
# scatter_by_param(i_data, 'md', True)
# scatter_by_param(i_data, 'e', True)
# scatter_by_param(i_data, 'mln', True)
# scatter_by_param(i_data, 'msl', True)
# scatter_by_param(i_data, 'mss', True)
# scatter_by_param(i_data, 'tdp', True)
# scatter_by_param(i_data, 'computer', True)
i_data.columns
# Out:
# Index(['status', 'e', 'md', 'mf', 'mln', 'msl', 'mss', 'tdp', 'computer',
#        'train time', 'predict time', 'diff mean', 'abs diff mean', 'diff var',
#        'abs diff var', 'median', 'mode', 'training time (hours)'],
#       dtype='object')

# %%
def scatter_by_param_2(data, param, add_var=False, title='', curve_fit= False):
    """creates color coded scatter plot by param for diff mean
    """
    colors = [  'slateblue', 'darkblue', 'cornflowerblue','skyblue']
    
    vals = data[param].unique()
    
    fig, ax = plt.subplots(figsize = (20, 12))
    
    cix = 0
    for v in vals:
        data[data[param] == v].plot.scatter(y = 'training time (hours)', x = 'diff mean' ,c=colors[cix], ax=ax, label= param + ' ' + str(v))
        cix += 1
    if add_var:
        data[data['diff var'] < 5].plot.scatter(y = 'training time (hours)', x = 'diff mean' ,
                            c='tab:orange',marker = '.', ax = ax, alpha = 1, label="Variance < 5")


#     if add_var:
#         data[data['abs diff var'] < 5].plot.scatter(y = 'training time (hours)', x = 'abs diff mean' ,
#                             c='tab:red',marker = '.', ax = ax, alpha = 1, label="Variance < 5")

    ax.set_xlabel('Mean Difference From Original Model')
    ax.set_ylabel('Training Time (Hours)')
    ax.legend()
    ax.set_title(title)

scatter_by_param_2(i_data, 'tdp', False)

# %%
i_data['training time (hours)'].cov(i_data['diff mean'])#('diff mean','training time (hours)')
# Out:
# 0.00030203039973230407

# %%
param = 'mss'
vals = i_data[param].unique()
for v in vals:
    ss = i_data[i_data[param] == v]
    print(v, ss['abs diff mean'].mean(), ss['abs diff var'].mean())
#     print(v, ss['diff mean'].mean(), ss['diff var'].mean())
print ('')
for v in vals:
    ss = i_data[i_data[param] == v]
#     print(v, ss['abs diff mean'].mean(), ss['abs diff var'].mean())
    print(v, ss['diff mean'].mean(), ss['diff var'].mean())
# Out:
# 2.0 3.384714890115292 10.23209330160868
# 5.0 3.3745619870195536 10.19152198032277
# 10.0 3.3705105274871623 10.164736344550088
#
# 2.0 -0.0013313126343385555 22.97219482904066
# 5.0 -0.001359945913686829 22.87650178394846
# 10.0 -0.0013389624553291257 22.794229548268973

# %%
# i_data['train time'].sort_values()

# %%
#i_data.to_csv('clean_data.csv')

# %%
l_c = []
for param in ['e', 'md', 'mf', 'mln', 'msl', 'mss', 'tdp', 'computer',]:
    print(param, i_data[param].unique())
    l_c.append(list(i_data[param].unique()))
    
print ('min abs diff mean',i_data['abs diff mean'].min())

p = 1
for l in l_c[:-1]:
    print(len(l))
    p *= len(l)
print(p)
4*4*3*4*4*3*3
# Out:
# e [ 10.  50. 100.]
# md [ 12.  25.  60. 100.]
# mf ['AUTO' 'SQRT' 'LOG2']
# mln [ 1000.  5000. 10000. 50000.]
# msl [1. 2. 4. 8.]
# mss [ 2.  5. 10.]
# tdp [25. 50. 75.]
# computer ['finwhale' 'ocotal' 'bristlecone' 'mac-chickadee']
# min abs diff mean 1.1460350482793569
# 3
# 4
# 3
# 4
# 4
# 3
# 3
# 5184
# 6912

# %% [markdown]
# # cell below is the hyperparameter 'seive'

# %%
print(i_data.columns)


idx_list = [('tdp',75),]# ('md',60), ('mf', 'AUTO'),('mln', 50000), ('msl', 4), ('mss',5), ('tdp',25)]
idx = i_data['e'] > 0


build_idx = lambda idx, data ,nf, nfv: np.logical_and(idx, data[nf] == nfv )

for i_l in idx_list:
    idx = build_idx(idx, i_data, i_l[0], i_l[1])

# print(i_data.shape)
print(i_data[idx].shape)
i_data[idx][['abs diff mean', 'abs diff var','training time (hours)']].sort_values('abs diff mean')[:10]
# Out:
# Index(['status', 'e', 'md', 'mf', 'mln', 'msl', 'mss', 'tdp', 'computer',
#        'train time', 'predict time', 'diff mean', 'abs diff mean', 'diff var',
#        'abs diff var', 'median', 'mode', 'training time (hours)'],
#       dtype='object')
# (1728, 18)
#                                                     abs diff mean  \
# name
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml        1.160473
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml         1.160473
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml        1.163443
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp75.yml         1.163486
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml        1.163487
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml        1.163487
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml        1.163487
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp75.yml         1.180241
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp75.yml       1.182403
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp75.yml         1.182418
#
#                                                     abs diff var  \
# name
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml       1.602006
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml        1.602006
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml       1.588280
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp75.yml        1.588269
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml       1.588262
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml       1.588262
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml       1.588262
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp75.yml        1.702501
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp75.yml      1.688901
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp75.yml        1.688786
#
#                                                     training time (hours)
# name
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml                1.874627
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml                 1.882754
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml                1.876119
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp75.yml                 1.870906
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml                1.893483
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml                1.893483
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml                1.893483
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp75.yml                 1.973292
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp75.yml               1.991090
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp75.yml                 1.970840

# %%
from pandas import Index
list_of_models = [
    'rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml','rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml','rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml','rfm_e10_md60_mfAUTO_mln50000_msl8_mss5_tdp50.yml','rfm_e10_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml','rfm_e10_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml','rfm_e100_md25_mfAUTO_mln50000_msl4_mss10_tdp25.yml','rfm_e100_md25_mfAUTO_mln50000_msl2_mss5_tdp25.yml','rfm_e100_md25_mfAUTO_mln50000_msl2_mss2_tdp25.yml','rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml','rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml','rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml',
]

# %% [markdown]
# # Save the baseline models timing

# %%
base_line_models = i_data[['diff mean','diff var','abs diff mean', 'abs diff var','training time (hours)']].ix[list_of_models].sort_values('abs diff mean')

base_line_models.columns = [[
    'mean difference', 'variance of difference', 
    'mean absolute difference', 'variance of absolute difference',
    'training time (hours)'

]]

base_line_models.to_csv('../results/baseline-models-accuracy.csv', index_label=False)
base_line_models
# Out:
#                                                    mean difference  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml         -0.002681
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml         -0.003108
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml         -0.003108
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml        -0.001127
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml         -0.001127
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml        -0.001199
# rfm_e100_md25_mfAUTO_mln50000_msl4_mss10_tdp25.yml       -0.002526
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss5_tdp25.yml        -0.002581
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss2_tdp25.yml        -0.002567
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss5_tdp50.yml         -0.002299
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml         -0.002299
# rfm_e10_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml       -0.002352
#
#                                                    variance of difference  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml                 3.039994
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                 2.976562
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                 2.976562
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml                2.948703
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml                 2.948703
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml                2.941877
# rfm_e100_md25_mfAUTO_mln50000_msl4_mss10_tdp25.yml               3.117974
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss5_tdp25.yml                3.101463
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss2_tdp25.yml                3.101660
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss5_tdp50.yml                 3.199154
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml                 3.199154
# rfm_e10_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml               3.176540
#
#                                                    mean absolute difference  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml                   1.146035
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                   1.146401
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                   1.146401
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml                  1.160473
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml                   1.160473
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml                  1.163443
# rfm_e100_md25_mfAUTO_mln50000_msl4_mss10_tdp25.yml                 1.171312
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss5_tdp25.yml                  1.173560
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss2_tdp25.yml                  1.173625
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss5_tdp50.yml                   1.190155
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml                   1.190155
# rfm_e10_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml                 1.192129
#
#                                                    variance of absolute difference  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml                          1.726605
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                          1.662335
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                          1.662335
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml                         1.602006
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml                          1.602006
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml                         1.588280
# rfm_e100_md25_mfAUTO_mln50000_msl4_mss10_tdp25.yml                        1.746009
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss5_tdp25.yml                         1.724226
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss2_tdp25.yml                         1.724271
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss5_tdp50.yml                          1.782691
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml                          1.782691
# rfm_e10_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml                        1.755374
#
#                                                    training time (hours)
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml                0.568037
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                0.564739
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                0.564739
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml               1.874627
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml                1.882754
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp75.yml               1.876119
# rfm_e100_md25_mfAUTO_mln50000_msl4_mss10_tdp25.yml              1.221215
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss5_tdp25.yml               1.224195
# rfm_e100_md25_mfAUTO_mln50000_msl2_mss2_tdp25.yml               1.231990
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss5_tdp50.yml                0.268454
# rfm_e10_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml                0.269072
# rfm_e10_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml              0.268874

# %%
def scatter_by_param_4(data, param, add_var=False, list_of_targets=[]):
    """creates color coded scatter plot by param for abs diff mean, also shows chosen models
    """
    colors = [  'slateblue', 'darkblue', 'cornflowerblue','skyblue']
    symbols = ['o','o','o','o']
    
    vals = data[param].unique()
    
    fig, ax = plt.subplots(figsize = (20, 12))
    
    cix = 0
#     for v in vals:
#         data[data[param] == v].plot.scatter(y = 'training time (hours)', x = 'abs diff mean'  ,alpha = .25, c=colors[cix], marker=symbols[cix], ax=ax, label= param + ' ' + str(v))
#         cix += 1
    if add_var:
        data[data['abs diff var'] < 5].plot.scatter(y = 'training time (hours)', x = 'abs diff mean' ,
                            c='tab:orange',marker = '.', ax = ax, alpha = .5, label="Variance < 5")

#     data.ix(np.array(list_of_targets))
#     for target in list_of_targets:
#         print (data.ix[target])
    i_data[['abs diff mean', 'abs diff var','training time (hours)']].ix[list_of_targets].plot.scatter(y = 'training time (hours)', x = 'abs diff mean' ,
                        c='tab:red',marker = 'o',s=80, ax = ax, alpha = 1, label="Variance < 5")
#     if add_var:
#         data[data['abs diff var'] < 5].plot.scatter(y = 'training time (hours)', x = 'abs diff mean' ,
#                             c='tab:red',marker = '.', ax = ax, alpha = 1, label="Variance < 5")

    ax.set_xlabel('Absoloute Mean Difference From Original Model')
    ax.set_ylabel('Training Time (Hours)')
    ax.legend()

# %%
scatter_by_param_4(i_data, 'md', True, list_of_models)

# %%
i_data['train time'].apply(to_td).sum()
# Out:
# Timedelta('125 days 17:38:38.230825')

# %%
idx_list = []
# idx_list.append(('tdp',75))
idx_list.append(('md',60)) 
# idx_list.append(('mf', 'AUTO'))
# idx_list.append(('mln', 50000))
# idx_list.append(('msl', 4))
# idx_list.append(('mss',5))
# idx_list.append(('tdp',25))
    
def build_index_adv(in_data, idx_list):
   
    idx = in_data['e'] > 0

    build_idx = lambda idx, data ,nf, nfv: np.logical_and(idx, data[nf] == nfv )

    for i_l in idx_list:
        idx = build_idx(idx, in_data, i_l[0], i_l[1])
    return idx


s_data = i_data[ build_index_adv (i_data, idx_list)]#.plot.scatter(y = 'training time (hours)', x = 'abs diff mean', ax =ax )


scatter_by_param(s_data, 'mln', title = "max depth = 25, max features = AUTO")

# %%
def seive_scatter(data, idx_list, high_light_feature, curve_fit = False):
    idx = build_index_adv(data,idx_list)
    title = "Scatter Where: "
    
    for item in idx_list:
        title += hp_lookup[item[0]] + ' = ' + str(item[1]) + ', '
        
    title = title[:-2] # remove last comma
    
    s_data = data[ build_index_adv (data, idx_list)]#.plot.scatter(y = 'training time (hours)', x = 'abs diff mean', ax =ax )
    scatter_by_param(s_data, high_light_feature, title = title, curve_fit=curve_fit)
   
   
def seive_scatter_m(data, idx_list, high_light_feature, curve_fit = False):
    idx = build_index_adv(data,idx_list)
    title = "Scatter Where: "
    
    for item in idx_list:
        title += hp_lookup[item[0]] + ' = ' + str(item[1]) + ', '
        
    title = title[:-2] # remove last comma
    
    s_data = data[ build_index_adv (data, idx_list)]#.plot.scatter(y = 'training time (hours)', x = 'abs diff mean', ax =ax )
    scatter_by_param_2(s_data, high_light_feature, title = title, curve_fit=curve_fit)

# %%
idx_list = []
# idx_list.append(('md',12)) 
idx_list.append(('mf', 'SQRT'))
# idx_list.append(('msl', 4))
# idx_list.append(('mss',10))
# idx_list.append(('tdp',25))

idx_list.append(('mln', 50000))

seive_scatter(data[data['md'] > 12], idx_list, 'mss', curve_fit= False)

# idx_list.pop()
# idx_list.append(('mln', 5000))
# seive_scatter(data, idx_list, 'mln', curve_fit= False)

# idx_list.pop()
# idx_list.append(('mln', 10000))
# seive_scatter(data, idx_list, 'mln', curve_fit= False)

# idx_list.pop()
# idx_list.append(('mln', 50000))
# seive_scatter(data, idx_list, 'mln', curve_fit= False)

# %%
def mean_by_parameter (c_data, param):




    u_values =  i_data[param].unique()


    stats = {}

    stats['all ' + param + ' mean'] = c_data['abs diff mean'].mean()
    stats['all ' + param + ' var'] = c_data['abs diff mean'].var()

    param_means = [stats['all ' + param + ' mean']]

    for val in u_values:
        stats[param + ' = ' + str(val) + ' mean'] = c_data[build_index_adv(c_data,[(param,val)])]['abs diff mean'].mean()
        stats[param + ' = ' + str(val) + ' var'] = c_data[build_index_adv(c_data,[(param,val)])]['abs diff mean'].var()
        param_means.append(stats[param + ' = ' + str(val) + ' mean'])


    stats['variance of each '+ param +' mean'] = np.array(param_means).var()
    
#     stats['key stat'] = stats['variance of each '+ param +' mean']

    return stats


c_data = i_data[i_data['md'] == 25]

seive_scatter(c_data, idx_list, 'msl', curve_fit= False)

mean_by_parameter(c_data[build_index_adv(c_data,idx_list)], 'msl')
# Out:
# {'all msl mean': 1.571440954917472,
#  'all msl var': 0.0031669153390013636,
#  'msl = 1.0 mean': 1.5711921163234963,
#  'msl = 1.0 var': 0.003030392821125434,
#  'msl = 2.0 mean': 1.5632349693668768,
#  'msl = 2.0 var': 0.003589609865546567,
#  'msl = 4.0 mean': 1.5679759875842112,
#  'msl = 4.0 var': 0.0035961511461387306,
#  'msl = 8.0 mean': 1.5800232047815104,
#  'msl = 8.0 var': 0.002919753993328766,
#  'variance of each msl mean': 3.0166658809403985e-05}

# %%
#what % or 100e models ran?
idx_all = full_data['e'] ==100

all_100 = full_data[idx_all].shape[0]

idx_run = full_data[idx_all]['status'] == 'complete'

run_100 = full_data[idx_all][idx_run].shape[0]

run_100/all_100 * 100
# Out:
# 83.02752293577981

# %%
# Out:
#                                                       status     e     md  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml    complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml   complete  50.0  100.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml   complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml    complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml    complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml   complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml   complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml   complete  50.0  100.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml   complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml    complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml  complete  50.0  100.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml  complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml   complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml   complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml    complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml    complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml    complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml   complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml  complete  50.0  100.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml   complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml    complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml   complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml   complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml    complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml   complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml    complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml   complete  50.0  100.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml    complete  50.0   60.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml    complete  50.0   60.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml   complete  50.0  100.0
# ...                                                      ...   ...    ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml     complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml   complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml   complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml   complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml   complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml     complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml    complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml    complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml     complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml     complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml     complete  10.0   12.0
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml     complete  10.0   12.0
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml     complete  10.0   12.0
#
#                                                       mf      mln  msl   mss  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml    AUTO  50000.0  8.0   5.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml   AUTO  50000.0  4.0   2.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml   AUTO  50000.0  4.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml    AUTO  50000.0  4.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml    AUTO  50000.0  8.0   2.0
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml   AUTO  50000.0  8.0   2.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml   AUTO  50000.0  2.0  10.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml   AUTO  50000.0  2.0   5.0
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml   AUTO  50000.0  2.0   2.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml    AUTO  50000.0  2.0   2.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml  AUTO  50000.0  1.0  10.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml  AUTO  50000.0  4.0  10.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml   AUTO  50000.0  4.0  10.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml   AUTO  50000.0  4.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml    AUTO  50000.0  4.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml    AUTO  50000.0  1.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml    AUTO  50000.0  1.0   2.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml   AUTO  50000.0  1.0  10.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml  AUTO  50000.0  1.0  10.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml   AUTO  50000.0  1.0   2.0
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml    AUTO  50000.0  1.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml   AUTO  50000.0  4.0  10.0
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml   AUTO  50000.0  1.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml    AUTO  50000.0  8.0   2.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml   AUTO  50000.0  8.0  10.0
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml    AUTO  50000.0  4.0   2.0
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml   AUTO  50000.0  8.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml    AUTO  50000.0  8.0   5.0
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml    AUTO  50000.0  2.0   5.0
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml   AUTO  50000.0  4.0   2.0
# ...                                                  ...      ...  ...   ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml     SQRT   5000.0  2.0   2.0
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml    SQRT  10000.0  1.0   2.0
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml    LOG2  50000.0  1.0   2.0
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml     SQRT   5000.0  1.0   2.0
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml    SQRT  10000.0  1.0   5.0
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml     SQRT   5000.0  1.0   5.0
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml    LOG2  50000.0  2.0   5.0
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml    LOG2  10000.0  2.0   5.0
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml    SQRT   5000.0  1.0  10.0
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml   LOG2  50000.0  2.0  10.0
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml    SQRT   5000.0  4.0  10.0
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml   SQRT  50000.0  4.0  10.0
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    LOG2  50000.0  4.0   2.0
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    LOG2  50000.0  4.0   2.0
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml   LOG2  10000.0  8.0  10.0
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml   LOG2  50000.0  8.0  10.0
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml     LOG2   5000.0  8.0   5.0
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml     LOG2   5000.0  8.0   2.0
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml    SQRT  50000.0  8.0   2.0
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml    LOG2  50000.0  8.0   2.0
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml    SQRT   1000.0  2.0  10.0
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml     LOG2   1000.0  2.0   2.0
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml     SQRT   1000.0  8.0   5.0
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml     SQRT   1000.0  1.0   5.0
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml     SQRT   1000.0  2.0   2.0
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml     LOG2   1000.0  1.0   2.0
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml     LOG2   1000.0  2.0   5.0
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml     LOG2   1000.0  8.0   5.0
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml     SQRT   1000.0  8.0   2.0
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml     SQRT   1000.0  1.0   2.0
#
#                                                      tdp       computer  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml    25.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml   25.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml   25.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml    25.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml    50.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml   50.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml   25.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml   25.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml   25.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml    25.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml  25.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml  50.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml   50.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml   50.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml    50.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml    25.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml    25.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml   50.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml  50.0    bristlecone
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml   50.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml    50.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml   25.0  mac-chickadee
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml   25.0  mac-chickadee
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml    25.0       finwhale
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml   25.0       finwhale
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml    25.0       finwhale
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml   75.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml    75.0    bristlecone
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml    25.0       finwhale
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml   50.0         ocotal
# ...                                                  ...            ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml     50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml     50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml     50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml   50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml   50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml   50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml   50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml     50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml     50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml    50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml    25.0    bristlecone
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml     25.0    bristlecone
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml     75.0    bristlecone
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml     75.0    bristlecone
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml     75.0    bristlecone
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml     75.0    bristlecone
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml     75.0    bristlecone
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml     50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml     50.0    bristlecone
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml     50.0    bristlecone
#
#                                                         train time  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml    0:34:04.931532
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml   0:34:23.755556
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml   0:34:18.075877
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml    0:33:53.060940
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml    1:12:51.591553
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml   1:14:00.400040
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml   0:34:02.142553
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml   0:34:09.556335
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml   0:34:20.209206
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml    0:34:18.246499
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml  0:34:03.685209
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml  1:13:29.279941
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml   1:13:21.001707
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml   1:13:19.501876
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml    1:13:13.261227
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml    0:34:08.230834
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml    0:33:56.881687
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml   1:12:55.362417
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml  1:12:38.022195
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml   1:12:37.263079
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml    1:13:02.521112
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml   0:38:42.135272
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml   0:38:41.169175
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml    0:35:26.676991
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml   0:35:20.415072
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml    0:35:27.004347
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml   1:52:28.658192
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml    1:52:57.913744
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml    0:35:27.462829
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml   2:09:37.574471
# ...                                                            ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml     0:02:44.927381
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml    0:02:44.957765
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml    0:02:45.636538
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml     0:02:42.306498
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml    0:02:44.694698
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml     0:02:45.483128
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml    0:02:44.450061
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml    0:02:44.898034
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml    0:02:41.417310
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml   0:02:44.440871
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml    0:02:45.716014
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml   0:02:45.164490
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    0:02:44.301805
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    0:02:44.301805
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml   0:02:44.272304
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml   0:02:45.873445
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml     0:02:44.674478
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml     0:02:45.565819
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml    0:02:45.489912
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml    0:02:45.734965
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml    0:01:20.523343
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml     0:01:16.898538
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml     0:04:05.255981
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml     0:04:03.337876
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml     0:04:03.672760
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml     0:04:04.249567
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml     0:04:03.039818
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml     0:02:40.509617
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml     0:02:40.452322
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml     0:02:40.687980
#
#                                                       predict time  diff mean  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml    0:00:44.847418  -0.002681
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml   0:00:44.871435  -0.003108
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml   0:00:44.852166  -0.003108
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml    0:00:44.975164  -0.003108
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml    0:00:44.624388  -0.002513
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml   0:00:44.793655  -0.002513
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml   0:00:44.661029  -0.003075
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml   0:00:45.035648  -0.003123
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml   0:00:45.226154  -0.003126
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml    0:00:44.748004  -0.003126
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml  0:00:44.772645  -0.003038
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml  0:00:45.104232  -0.002545
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml   0:00:44.327242  -0.002545
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml   0:00:45.314711  -0.002558
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml    0:00:45.163830  -0.002558
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml    0:00:44.887414  -0.003099
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml    0:00:44.556634  -0.003049
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml   0:00:44.548125  -0.002563
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml  0:00:44.452638  -0.002563
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml   0:00:44.752374  -0.002557
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml    0:00:44.094971  -0.002558
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml   0:00:47.746939  -0.002728
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml   0:00:47.765958  -0.002765
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml    0:00:45.553858  -0.003713
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml   0:00:45.564657  -0.003713
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml    0:00:45.876276  -0.003768
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml   0:00:45.156747  -0.001127
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml    0:00:44.910325  -0.001127
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml    0:00:45.651271  -0.003802
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml   0:01:16.944342  -0.001610
# ...                                                            ...        ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml     0:00:05.559593  -0.000112
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml    0:00:05.561258  -0.000114
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml    0:00:05.569490  -0.000114
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml     0:00:05.560965  -0.000114
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml    0:00:05.558659  -0.000085
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml     0:00:05.558015  -0.000085
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml    0:00:05.580862  -0.000106
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml    0:00:05.457877  -0.000106
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml    0:00:05.656713  -0.000068
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml   0:00:05.562354  -0.000064
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml    0:00:05.582381  -0.000110
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml   0:00:05.468955  -0.000110
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    0:00:05.583685  -0.000118
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml    0:00:05.583685  -0.000118
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml   0:00:05.574222  -0.000107
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml   0:00:05.659694  -0.000107
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml     0:00:05.567873  -0.000107
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml     0:00:05.601380  -0.000107
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml    0:00:05.594979  -0.000107
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml    0:00:05.606064  -0.000107
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml    0:00:05.464158   0.000764
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml     0:00:05.356510   0.000796
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml     0:00:05.361398  -0.000140
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml     0:00:05.469551  -0.000118
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml     0:00:05.371613  -0.000118
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml     0:00:05.355338  -0.000118
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml     0:00:05.370636  -0.000118
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml     0:00:05.377156  -0.000259
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml     0:00:05.359529  -0.000259
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml     0:00:05.365953  -0.000270
#
#                                                     abs diff mean   diff var  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml         1.146035   3.039994
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml        1.146401   2.976562
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml        1.146401   2.976562
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml         1.146401   2.976562
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml         1.147438   2.940239
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml        1.147438   2.940239
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml        1.147895   2.961271
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml        1.148517   2.961819
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml        1.148612   2.962087
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml         1.148612   2.962087
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml       1.149244   2.960190
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml       1.149792   2.922341
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml        1.149792   2.922341
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml        1.149862   2.922472
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml         1.149862   2.922472
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml         1.149870   2.960332
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml         1.150021   2.960779
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml        1.151668   2.920222
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml       1.151668   2.920222
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml        1.151834   2.920544
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml         1.151839   2.920590
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml        1.152318   2.994397
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml        1.156304   2.979012
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml         1.158823   3.126611
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml        1.158823   3.126611
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml         1.159257   3.056665
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml        1.160473   2.948703
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml         1.160473   2.948703
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml         1.161552   3.040353
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml        1.161803   2.970827
# ...                                                           ...        ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml          4.923525  42.070504
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml         4.923749  42.072422
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml         4.923749  42.072422
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml          4.923749  42.072422
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml         4.923753  42.069569
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml          4.923753  42.069569
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml         4.923817  42.070621
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml         4.923817  42.070621
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml         4.924189  42.082768
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml        4.924312  42.084475
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml         4.924383  42.089528
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml        4.924383  42.089528
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml         4.924652  42.087667
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml         4.924652  42.087667
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml        4.925276  42.092313
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml        4.925276  42.092313
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml          4.925276  42.092313
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml          4.925276  42.092313
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml         4.925276  42.092313
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml         4.925276  42.092313
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml         4.978007  42.819649
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml          4.978865  42.826761
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml          5.023913  43.486225
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml          5.024047  43.486842
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml          5.024047  43.486842
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml          5.024047  43.486842
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml          5.024047  43.486842
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml          5.052571  43.904988
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml          5.052571  43.904988
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml          5.052715  43.899315
#
#                                                     abs diff var    median  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml        1.726605  0.008198
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml       1.662335  0.007719
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml       1.662335  0.007719
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml        1.662335  0.007719
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml        1.623631  0.007952
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml       1.623631  0.007952
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml       1.643617  0.007651
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml       1.642738  0.007644
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml       1.642787  0.007652
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml        1.642787  0.007652
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml      1.639437  0.007693
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml      1.600327  0.007616
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml       1.600327  0.007616
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml       1.600295  0.007596
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml        1.600295  0.007596
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml        1.638140  0.007611
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml        1.638240  0.007686
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml       1.593890  0.007522
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml      1.593890  0.007522
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml       1.593829  0.007542
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml        1.593864  0.007556
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml       1.666568  0.007646
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml       1.641980  0.007619
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml        1.783754  0.007760
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml       1.783754  0.007760
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml        1.712803  0.007284
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml       1.602006  0.007238
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml        1.602006  0.007238
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml        1.691163  0.007180
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml       1.621044  0.008204
# ...                                                          ...       ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml        17.829409  0.416919
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml       17.829120  0.416167
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml       17.829120  0.416167
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml        17.829120  0.416167
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml       17.826229  0.417386
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml        17.826229  0.417386
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml       17.826644  0.417496
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml       17.826644  0.417496
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml       17.835128  0.414784
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml      17.835625  0.415080
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml       17.839980  0.414012
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml      17.839980  0.414012
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml       17.835467  0.415068
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml       17.835467  0.415068
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml      17.833969  0.413222
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml      17.833969  0.413222
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml        17.833969  0.413222
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml        17.833969  0.413222
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml       17.833969  0.413222
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml       17.833969  0.413222
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml       18.039092  0.399205
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml        18.037661  0.398929
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml        18.246527  0.429842
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml        18.245794  0.430330
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml        18.245794  0.430330
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml        18.245794  0.430330
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml        18.245794  0.430330
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml        18.376516  0.432357
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml        18.376516  0.432357
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml        18.369386  0.435026
#
#                                                     mode  \
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml     NaN
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml    NaN
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml     NaN
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml     NaN
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml    NaN
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml    NaN
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml     NaN
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml   NaN
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml   NaN
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml    NaN
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml     NaN
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml     NaN
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml     NaN
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml    NaN
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml   NaN
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml     NaN
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml    NaN
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml     NaN
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml     NaN
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml    NaN
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml     NaN
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml     NaN
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml    NaN
# ...                                                  ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml      NaN
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml     NaN
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml     NaN
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml      NaN
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml     NaN
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml      NaN
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml     NaN
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml     NaN
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml     NaN
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml    NaN
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml     NaN
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml    NaN
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml     NaN
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml     NaN
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml    NaN
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml    NaN
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml      NaN
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml      NaN
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml     NaN
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml     NaN
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml     NaN
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml      NaN
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml      NaN
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml      NaN
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml      NaN
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml      NaN
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml      NaN
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml      NaN
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml      NaN
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml      NaN
#
#                                                     training time (hours)
# name
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml                 0.568037
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp25.yml                0.573265
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp25.yml                0.571688
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp25.yml                 0.564739
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp50.yml                 1.214331
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss2_tdp50.yml                1.233444
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss10_tdp25.yml                0.567262
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp25.yml                0.569321
# rfm_e50_md100_mfAUTO_mln50000_msl2_mss2_tdp25.yml                0.572280
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss2_tdp25.yml                 0.571735
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp25.yml               0.567690
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss10_tdp50.yml               1.224800
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp50.yml                1.222500
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss5_tdp50.yml                1.222084
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss5_tdp50.yml                 1.220350
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp25.yml                 0.568953
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss2_tdp25.yml                 0.565800
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss10_tdp50.yml                1.215378
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss10_tdp50.yml               1.210562
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss2_tdp50.yml                1.210351
# rfm_e50_md60_mfAUTO_mln50000_msl1_mss5_tdp50.yml                 1.217367
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss10_tdp25.yml                0.645038
# rfm_e50_md100_mfAUTO_mln50000_msl1_mss5_tdp25.yml                0.644769
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss2_tdp25.yml                 0.590744
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss10_tdp25.yml                0.589004
# rfm_e50_md60_mfAUTO_mln50000_msl4_mss2_tdp25.yml                 0.590835
# rfm_e50_md100_mfAUTO_mln50000_msl8_mss5_tdp75.yml                1.874627
# rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp75.yml                 1.882754
# rfm_e50_md60_mfAUTO_mln50000_msl2_mss5_tdp25.yml                 0.590962
# rfm_e50_md100_mfAUTO_mln50000_msl4_mss2_tdp50.yml                2.160437
# ...                                                                   ...
# rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml                  0.045813
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss2_tdp50.yml                 0.045822
# rfm_e10_md12_mfLOG2_mln50000_msl1_mss2_tdp50.yml                 0.046010
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss2_tdp50.yml                  0.045085
# rfm_e10_md12_mfSQRT_mln10000_msl1_mss5_tdp50.yml                 0.045749
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss5_tdp50.yml                  0.045968
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss5_tdp50.yml                 0.045681
# rfm_e10_md12_mfLOG2_mln10000_msl2_mss5_tdp50.yml                 0.045805
# rfm_e10_md12_mfSQRT_mln5000_msl1_mss10_tdp50.yml                 0.044838
# rfm_e10_md12_mfLOG2_mln50000_msl2_mss10_tdp50.yml                0.045678
# rfm_e10_md12_mfSQRT_mln5000_msl4_mss10_tdp50.yml                 0.046032
# rfm_e10_md12_mfSQRT_mln50000_msl4_mss10_tdp50.yml                0.045879
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml                 0.045639
# rfm_e10_md12_mfLOG2_mln50000_msl4_mss2_tdp50.yml                 0.045639
# rfm_e10_md12_mfLOG2_mln10000_msl8_mss10_tdp50.yml                0.045631
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss10_tdp50.yml                0.046076
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss5_tdp50.yml                  0.045743
# rfm_e10_md12_mfLOG2_mln5000_msl8_mss2_tdp50.yml                  0.045991
# rfm_e10_md12_mfSQRT_mln50000_msl8_mss2_tdp50.yml                 0.045969
# rfm_e10_md12_mfLOG2_mln50000_msl8_mss2_tdp50.yml                 0.046037
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss10_tdp25.yml                 0.022368
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss2_tdp25.yml                  0.021361
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss5_tdp75.yml                  0.068127
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss5_tdp75.yml                  0.067594
# rfm_e10_md12_mfSQRT_mln1000_msl2_mss2_tdp75.yml                  0.067687
# rfm_e10_md12_mfLOG2_mln1000_msl1_mss2_tdp75.yml                  0.067847
# rfm_e10_md12_mfLOG2_mln1000_msl2_mss5_tdp75.yml                  0.067511
# rfm_e10_md12_mfLOG2_mln1000_msl8_mss5_tdp50.yml                  0.044586
# rfm_e10_md12_mfSQRT_mln1000_msl8_mss2_tdp50.yml                  0.044570
# rfm_e10_md12_mfSQRT_mln1000_msl1_mss2_tdp50.yml                  0.044636
#
# [5195 rows x 18 columns]

# %%
# Out:
#                                                   name    status      e  \
# 0     rfm_e50_md60_mfAUTO_mln50000_msl8_mss5_tdp25.yml  complete   50.0
# 1    rfm_e50_md100_mfAUTO_mln50000_msl2_mss5_tdp75.yml  complete   50.0
# 2     rfm_e50_md25_mfAUTO_mln50000_msl8_mss5_tdp25.yml  complete   50.0
# 3    rfm_e100_md25_mfAUTO_mln50000_msl4_mss5_tdp75.yml  complete  100.0
# 4    rfm_e10_md100_mfAUTO_mln50000_msl8_mss5_tdp25.yml  complete   10.0
# ..                                                 ...       ...    ...
# 255    rfm_e10_md12_mfLOG2_mln1000_msl4_mss5_tdp25.yml   not run   10.0
# 256    rfm_e10_md12_mfLOG2_mln1000_msl4_mss2_tdp50.yml   not run   10.0
# 257    rfm_e50_md12_mfSQRT_mln1000_msl2_mss5_tdp75.yml   not run   50.0
# 258   rfm_e10_md12_mfLOG2_mln50000_msl2_mss2_tdp75.yml   not run   10.0
# 259    rfm_e10_md12_mfSQRT_mln5000_msl2_mss2_tdp50.yml   not run   10.0
#
#         md    mf      mln  msl  mss   tdp     computer      train time  \
# 0     60.0  AUTO  50000.0  8.0  5.0  25.0       ocotal  0:41:20.608450
# 1    100.0  AUTO  50000.0  2.0  5.0  75.0     finwhale  1:17:26.933209
# 2     25.0  AUTO  50000.0  8.0  5.0  25.0  bristlecone  0:22:37.552727
# 3     25.0  AUTO  50000.0  4.0  5.0  75.0  bristlecone  2:47:51.164530
# 4    100.0  AUTO  50000.0  8.0  5.0  25.0       ocotal  0:05:39.008684
# ..     ...   ...      ...  ...  ...   ...          ...             ...
# 255   12.0  LOG2   1000.0  4.0  5.0  25.0          NaN             NaN
# 256   12.0  LOG2   1000.0  4.0  2.0  50.0          NaN             NaN
# 257   12.0  SQRT   1000.0  2.0  5.0  75.0          NaN             NaN
# 258   12.0  LOG2  50000.0  2.0  2.0  75.0          NaN             NaN
# 259   12.0  SQRT   5000.0  2.0  2.0  50.0          NaN             NaN
#
#        predict time  diff mean  abs diff mean  diff var  abs diff var  \
# 0    0:00:39.996300  -0.002525       1.157600  3.138042      1.798010
# 1    0:00:29.521916  -0.001159       1.182020  3.079123      1.681952
# 2    0:00:30.633898  -0.002209       1.186380  3.298571      1.891078
# 3    0:00:57.936676  -0.001004       1.196938  3.181765      1.749105
# 4    0:00:09.500778  -0.002824       1.209078  3.456397      1.994536
# ..              ...        ...            ...       ...           ...
# 255             NaN        NaN            NaN       NaN           NaN
# 256             NaN        NaN            NaN       NaN           NaN
# 257             NaN        NaN            NaN       NaN           NaN
# 258             NaN        NaN            NaN       NaN           NaN
# 259             NaN        NaN            NaN       NaN           NaN
#
#        median  mode  training time (hours)       r^2
# 0    0.008117   NaN                    NaN  0.983808
# 1    0.008469   NaN                    NaN  0.984112
# 2    0.011955   NaN                    NaN  0.982979
# 3    0.010865   NaN                    NaN  0.983582
# 4    0.008942   NaN                    NaN  0.982165
# ..        ...   ...                    ...       ...
# 255       NaN   NaN                    NaN       NaN
# 256       NaN   NaN                    NaN       NaN
# 257       NaN   NaN                    NaN       NaN
# 258       NaN   NaN                    NaN       NaN
# 259       NaN   NaN                    NaN       NaN
#
# [260 rows x 20 columns]
